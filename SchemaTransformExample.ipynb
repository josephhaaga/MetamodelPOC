# %% [markdown]
# # Schema Transform Example
# In this example, we persist a source graph's metadata in Grakn, perform a motif query to 'transform' the graph, and document the updated schema. Ideally, generated code snippets will apply the transforms to the source graph in Spark.

# %% [markdown]
# ## Source Graph

# %%
# ! pip install findspark

# %%
# !pip install graphframes
# https://towardsdatascience.com/graphframes-in-jupyter-a-practical-guide-9b3b346cebc5

# %%
import findspark
findspark.init()

# %%
from pyspark import SparkContext, SparkConf
from pyspark.sql import SparkSession, SQLContext, DataFrame
from pyspark.conf import SparkConf

# %%
sc = SparkContext.getOrCreate(SparkConf().setMaster("local[*]"))
sqlC = SQLContext(sc)
sc.addPyFile("/Users/josephhaaga/.ivy2/jars/graphframes_graphframes-0.6.0-spark2.3-s_2.11.jar")

# %%
edges = sqlC.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("./data/peopleAndCompanies_edges.csv") 
    
vertices = sqlC.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("./data/peopleAndCompanies_vertices.csv")

# %%
vertices.toPandas()
# Out:
#       id     type                        name  \
# 0      0  company                Cooper-Green
# 1      1  company           Williams-Figueroa
# 2      2  company                  Montes LLC
# 3      3  company                Gomez-Morgan
# 4      4  company                 Bowen-Payne
# 5      5  company               Smith-Jimenez
# 6      6  company             Brandt and Sons
# 7      7  company             Patterson-Allen
# 8      8  company               Rivera-Taylor
# 9      9  company                  Peters Ltd
# 10    10  company              Stephens-Green
# 11    11  company    Craig, Harris and Hudson
# 12    12  company             Thomas and Sons
# 13    13  company     Scott, Miller and Doyle
# 14    14  company                  Hudson Inc
# 15    15  company      Smith, Reed and Flores
# 16    16  company                  Harris Inc
# 17    17  company  Diaz, Sanchez and Williams
# 18    18  company                   Jones Inc
# 19    19  company                  Holmes Ltd
# 20    20   person               Margaret Khan
# 21    21   person               Terry Herring
# 22    22   person             Mariah Peterson
# 23    23   person               Jeffrey Baird
# 24    24   person                 Grant Smith
# 25    25   person                 Mary Turner
# 26    26   person                  Thomas Lin
# 27    27   person                 Judy Powell
# 28    28   person            Dr. Eric Ramirez
# 29    29   person               Lisa Cardenas
# ..   ...      ...                         ...
# 90    90   person              Patrick Morrow
# 91    91   person                Sarah Garcia
# 92    92   person                 Anita Jones
# 93    93   person               Thomas Arnold
# 94    94   person                Amanda Burke
# 95    95   person               Evan Whitaker
# 96    96   person               Tracy Mcgrath
# 97    97   person                 Henry Scott
# 98    98   person                  Paul Ayers
# 99    99   person             Kimberly Steele
# 100  100   person                Jon Chandler
# 101  101   person                 Andrew Cain
# 102  102   person                 Emily Salas
# 103  103   person              Connor Estrada
# 104  104   person                   Luis King
# 105  105   person                 Kevin Davis
# 106  106   person                Traci Morris
# 107  107   person              Johnathan Cook
# 108  108   person              Melinda Duncan
# 109  109   person              Ashley Sanders
# 110  110   person                Madison Hall
# 111  111   person                Sara Walters
# 112  112   person               Aaron Francis
# 113  113   person                  Adam Kelly
# 114  114   person               Mark Anderson
# 115  115   person                 Scott Clark
# 116  116   person             Dr. Dustin Meza
# 117  117   person                 Steven Beck
# 118  118   person                  Keith Barr
# 119  119   person                 Tina Wright
#
#                                                address
# 0      6647 Roger Walks Suite 088 Julieburgh, NY 53881
# 1         65694 Maureen Mountain Morganhaven, ND 01430
# 2        2464 Mark Unions Suite 345 Johnview, MN 95700
# 3                 565 Jason Park Thomasmouth, TX 84271
# 4    6161 Lynn Summit Suite 881 South Darleneshire,...
# 5    34537 Briggs Light Suite 173 Danielfort, GA 06278
# 6    43659 Butler Shores Apt. 723 Juliachester, NJ ...
# 7    04097 Turner Lake Apt. 998 Robinsonfurt, WA 58520
# 8           014 Jeffrey Pines West Bobbyfort, OK 65867
# 9       398 Cortez Point Suite 413 Kevintown, NC 49123
# 10             39626 Ray Trafficway Loveland, KS 21912
# 11           6376 Barbara Place Charlesmouth, NE 68891
# 12                             USNS Owens FPO AE 57568
# 13   894 Blackburn Lake Suite 722 Christopherville,...
# 14   19686 Carter Station Suite 651 Melissamouth, G...
# 15   6892 Sanchez Union Suite 513 Stewarttown, NC 6...
# 16         024 Good Overpass New Lesliehaven, NC 62986
# 17   00807 Meadows Prairie Apt. 382 East Melaniebur...
# 18                     Unit 5674 Box 1556 DPO AA 42502
# 19   90746 Beasley Shoal Suite 136 New Joseph, WA 4...
# 20           1533 Frederick Alley Jamesmouth, SD 62854
# 21   7340 Simmons Square Apt. 770 Isabellaville, MS...
# 22            829 Combs Expressway Jamesstad, VT 68867
# 23      49842 Christopher Ports Christianton, AR 61646
# 24   5123 Buckley Harbor Apt. 998 Alexandertown, KS...
# 25     9789 Ashley Cliff Apt. 839 Ronaldbury, PA 05624
# 26   9258 Taylor Trafficway Apt. 368 Lake Ambermout...
# 27               064 Derek Ports North James, WA 79348
# 28   29498 Samantha Trafficway East Dominiqueboroug...
# 29     3221 John Manor Suite 049 West Rodney, OR 84221
# ..                                                 ...
# 90               991 Berry Wells Robertmouth, AZ 71820
# 91   00033 Scott Pines Apt. 545 East Caitlinberg, I...
# 92   748 David Circle Apt. 263 Port Davidview, NH 5...
# 93   714 Cobb Rapid Apt. 132 North Brandybury, LA 1...
# 94     90844 Lisa Plain Suite 486 Bradymouth, WI 17998
# 95        97035 Darren Divide Port Carmenton, MT 95218
# 96          94965 Carter Groves Jenniferland, WA 98168
# 97   2278 Green Course Suite 245 New Caitlinbury, M...
# 98    9762 Keith Mountain Apt. 424 Goodburgh, NV 18140
# 99      49953 Joseph Centers North Brianberg, WV 52589
# 100       92071 Shannon Burgs South Ryanport, NC 27712
# 101            141 Mcdonald Way Thorntonport, WI 94935
# 102              638 Rice Curve West Michael, MT 63930
# 103                            USS Murray FPO AA 23272
# 104           243 Stafford Trail Marychester, AR 45390
# 105  373 Mccullough Turnpike Suite 154 South Joshua...
# 106  85169 Christian Ranch Suite 478 New Travisvill...
# 107              81040 Dennis Parks Reidfort, WA 29386
# 108              415 Lisa Mills South Austin, GA 42398
# 109      496 Andrew Glen Suite 687 Lake Eric, NY 37737
# 110           5873 Peterson Forks Georgeport, VA 27520
# 111  30344 Angelica Roads Apt. 802 East Ashleyview,...
# 112                0880 Obrien Loop Adamside, OK 36437
# 113               1420 Juan Pine Taylormouth, MT 03389
# 114              329 Bowman Ways Fischerberg, MN 72141
# 115  61695 Scott Highway Suite 380 New Staceyhaven,...
# 116  18876 Wong Fall Apt. 603 Richardsonmouth, WA 1...
# 117      7993 Daniel Flats West Laurachester, WI 62541
# 118              784 Davis Prairie Davisside, DE 73387
# 119  56731 Patel Extension Suite 422 New Lori, UT 8...
#
# [120 rows x 4 columns]

# %%
from graphframes import *
# https://stackoverflow.com/a/50404308

# %%
g = GraphFrame(vertices, edges)

# %%
# Dependents claiming dependents
g.find("(a)-[r]->(b); (b)-[r2]->(c)") \
    .filter("r.relationship == 'claims_dependent'") \
    .filter("r2.relationship == 'claims_dependent'").show()
# Out:
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |                   a|                   r|                   b|                  r2|                   c|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# |[22, person, Mari...|[22, 66, claims_d...|[66, person, Andr...|[66, 69, claims_d...|[69, person, Javi...|
# |[22, person, Mari...|[22, 88, claims_d...|[88, person, Caro...|[88, 34, claims_d...|[34, person, Tyle...|
# |[22, person, Mari...|[22, 88, claims_d...|[88, person, Caro...|[88, 92, claims_d...|[92, person, Anit...|
# |[22, person, Mari...|[22, 25, claims_d...|[25, person, Mary...|[25, 58, claims_d...|[58, person, Dona...|
# |[26, person, Thom...|[26, 45, claims_d...|[45, person, Terr...|[45, 47, claims_d...|[47, person, Geor...|
# |[29, person, Lisa...|[29, 71, claims_d...|[71, person, Evan...|[71, 58, claims_d...|[58, person, Dona...|
# |[35, person, Devi...|[35, 36, claims_d...|[36, person, Holl...|[36, 56, claims_d...|[56, person, Will...|
# |[40, person, Step...|[40, 64, claims_d...|[64, person, Alex...|[64, 98, claims_d...|[98, person, Paul...|
# |[49, person, Jame...|[49, 66, claims_d...|[66, person, Andr...|[66, 69, claims_d...|[69, person, Javi...|
# |[52, person, Jenn...|[52, 40, claims_d...|[40, person, Step...|[40, 64, claims_d...|[64, person, Alex...|
# |[57, person, Nich...|[57, 34, claims_d...|[34, person, Tyle...|[34, 20, claims_d...|[20, person, Marg...|
# |[63, person, Nico...|[63, 76, claims_d...|[76, person, Ange...|[76, 57, claims_d...|[57, person, Nich...|
# |[63, person, Nico...|[63, 57, claims_d...|[57, person, Nich...|[57, 34, claims_d...|[34, person, Tyle...|
# |[63, person, Nico...|[63, 57, claims_d...|[57, person, Nich...|[57, 44, claims_d...|[44, person, Shei...|
# |[63, person, Nico...|[63, 57, claims_d...|[57, person, Nich...|[57, 58, claims_d...|[58, person, Dona...|
# |[75, person, Lee ...|[75, 26, claims_d...|[26, person, Thom...|[26, 45, claims_d...|[45, person, Terr...|
# |[75, person, Lee ...|[75, 26, claims_d...|[26, person, Thom...|[26, 33, claims_d...|[33, person, Jack...|
# |[75, person, Lee ...|[75, 26, claims_d...|[26, person, Thom...|[26, 94, claims_d...|[94, person, Aman...|
# |[76, person, Ange...|[76, 57, claims_d...|[57, person, Nich...|[57, 34, claims_d...|[34, person, Tyle...|
# |[76, person, Ange...|[76, 57, claims_d...|[57, person, Nich...|[57, 44, claims_d...|[44, person, Shei...|
# +--------------------+--------------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ## Describe Source Graph in Grakn Metamodel
# The source graph, a GraphFrame named `g`, depicts a network of people claiming eachother as dependents. We need methods to extract the relevant features of this graph so that it can be depicted in the Grakn metamodel. Some examples of things we need to describe include:

# %% [markdown]
# ### graphVertex
# - Attributes
#     - Name
# - Relationships
#     - has-type
#     - has-graphobjects
#     - has-concept
#     - has-vertexid
#     - has_property
#     - has-attribute

# %%
import uuid

# %% [markdown]
# #### Can GraphFrames give a list of the different vertex types?
# e.g: `g.vertices.types`
#
# It looks like GraphFrame has weak support for multiple vertex types in the same graph. This will require manual intervention in the metamodel creation. Or we can insert a Type column into the vertex DataFrame.
# https://forums.databricks.com/questions/7792/with-graphframes-are-there-ways-of-dealing-with-mu.html

# %%
# vertexTypes = ["Person"]
vertexTypes = g.vertices.select("type").distinct().rdd.flatMap(lambda x: x).collect()

# A more interesting graph would have multiple vertex types e.g.
# types = ["Person", "Return", "Company"]

createVertices = ['insert $'+str(uuid.uuid4())+' isa graphVertex has name "'+v+'";' \
 for v in vertexTypes]

# insert statements may need to become match-insert statements if we want to update existing metamodel graphs

createVertices
# Out:
# ['insert $23b71f90-3b2c-475e-9beb-98853329b257 isa graphVertex has name "person";',
#  'insert $6256bbe3-f48e-42e4-b1c9-edfa46037e8f isa graphVertex has name "company";']

# %% [markdown]
# ### graphEdge
# - Attributes
#     - Name
# - Relationships
#     - has-type
#     - has-graphobjects
#     - has-concept
#     - has-edgeids
#     - has_property
#     - has-attribute

# %%
edgeTypes = g.edges.select("relationship").distinct().rdd.flatMap(lambda x: x).collect()
createEdges = ['insert $'+str(uuid.uuid4())+' isa graphEdge has name "'+e+'";' \
 for e in edgeTypes]

createEdges
# Out:
# ['insert $30b6d21a-b030-412f-9d2f-b2bd4bfb6c5f isa graphEdge has name "owned_by";',
#  'insert $dfd916b0-7640-4783-a700-da9867967ca1 isa graphEdge has name "employed_by";',
#  'insert $8d8e2e02-94c8-4c28-988c-8d7bbb0abad0 isa graphEdge has name "claims_dependent";']

# %% [markdown]
# ### graphTriplet
# This may benefit from making owned_by an ambigious relationship (e.g. Company can be owned_by another Company or Person). This can be changed in the GeneratePeopleAndCompanies.ipynb notebook.

# %%
# Try to get the nodeType -> relationshipType -> nodeType triples from GraphFrame for insertion into metamodel
g.edges
# Out:
# DataFrame[src: int, dst: int, relationship: string]

# %%
g.vertices.
# Out:
#   File "<ipython-input-23-f29cdcf28f6a>", line 1
#     g.vertices.
#                ^
# SyntaxError: invalid syntax

# %%
createRelationships = ['insert $'+str(uuid.uuid4())+' isa graphEdge has name "'+e+'";' \
 for e in ]
# Out:
#   File "<ipython-input-15-2ab630cd75c2>", line 2
#     createRelationships = ['insert $'+str(uuid.uuid4())+' isa graphEdge has name "'+e+'";'  for e in ]
#                                                                                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### graphAttribute
